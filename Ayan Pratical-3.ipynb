# %%
import pandas as pd

# %%
df = pd.DataFrame({"Roll no": [4,5], "Name": ['Yash', 'Ayan']})

# %%
df

# %%
df = pd.DataFrame([[4,5,7],[4,6,8],[9,9,9]], index=[1,2,3], columns=['a', 'b', 'c'])

# %%
df
# Out:
#    a  b  c
# 1  4  5  7
# 2  4  6  8
# 3  9  9  9

# %%
df.iloc[:,0:]
# Out:
#    a  b  c
# 1  4  5  7
# 2  4  6  8
# 3  9  9  9

# %%
df.iloc[:,1:2]
# Out:
#    b
# 1  5
# 2  6
# 3  9

# %%
df.iloc[:,:2]
# Out:
#    a  b
# 1  4  5
# 2  4  6
# 3  9  9

# %%
df.loc[:, 'x1' :'x4']
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 2, 3]

# %%
df=pd.read_csv('gender_submission.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.6 KB

# %%
tested = pd.read_csv("gender_submission.csv")

# %%
tested.iloc[3:5, 0:2]
# Out:
#    PassengerId  Survived
# 3          895         0
# 4          896         1

# %%
tested.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
tested.iloc[0:5]
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
tested.tail()
# Out:
#      PassengerId  Survived
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0

# %%
tested.shape
# Out:
# (418, 2)

# %%
tested.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.6 KB

# %%
tested.columns
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %%
tested.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
tested.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
tested.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
tested.fillna(0, inplace=True)
